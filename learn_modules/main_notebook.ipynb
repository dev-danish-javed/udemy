# %%
from learn_modules.greeting.see_off import say_bye
# from learn_modules.greeting.see_off import say_bye
# from learn_modules.greeting.welcome import say_hi

# say_hi()
say_bye()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from learn_modules.greeting.see_off import say_bye
#       2 # from learn_modules.greeting.see_off import say_bye
#       3 # from learn_modules.greeting.welcome import say_hi
#       4
#       5 # say_hi()
#       6 say_bye()
#
# ModuleNotFoundError: No module named 'learn_modules.greeting.see_off'
