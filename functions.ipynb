# %%
def greet(name:str, location:str):
    print(f"Hello {name}, your location is {location}")

# %%
greet("Danish", "Noida")
greet(name="Danish", location="New York")
greet(location="Kolkata", name="Danish")
# Out:
# Hello Danish, your location is Noida
# Hello Danish, your location is New York
# Hello Danish, your location is Kolkata

# %%
numbers_a = [1,2,3]
numbers_b = [4,5,6]
sum = list(map(lambda x,y : x+y, numbers_a, numbers_b))
print(sum)
# Out:
# [5, 7, 9]
